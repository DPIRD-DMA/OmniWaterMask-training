# %% [markdown]
# # Dataset Tiling and Mask Preparation
#
# In this notebook, the **S1S2 dataset** is split into **512 × 512 pixel tiles** with a small amount of overlap.
#
# Some images contain **NoData regions**. These regions are indicated in the corresponding *validity masks*, where:
#
# - `0` → Invalid (NoData)
# - `1` → Valid
#
# To ensure these areas are ignored during training:
#
# - All invalid (`0`) pixels from the validity mask are **burned into the segmentation mask** using the value `99`.
# - The value `99` is configured as an **ignore label** during model training.
#
# This approach prevents NoData regions from influencing the loss or evaluation metrics.

# %%
from pathlib import Path
import rasterio as rio
from tqdm.auto import tqdm
import json
import numpy as np

from multiprocessing import Pool
from multiprocessing.pool import ThreadPool

# %%
patch_size = 512
water_value = 1
background_value = 0
stride = 412
do_L2A = True
image_bands = [1, 2, 3, 4]
expected_image_channels = len(image_bands)

# %%
data_dir = Path("/media/nick/4TB Working 6/Datasets/S1S2-Water/train")

# %%
img_patches_dir = data_dir / "images"
mask_patches_dir = data_dir / "labels"

img_patches_dir.mkdir(exist_ok=True, parents=True)
mask_patches_dir.mkdir(exist_ok=True)
img_patches_dir, mask_patches_dir
# Out:
# (PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/train/images'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/train/labels'))

# %%
s1s2_folders = data_dir.parent
s1s2_folders.exists()
# Out:
# True

# %%
part_folders = list(
    set(s1s2_folders.glob("part*")) - set(s1s2_folders.glob("part*.zip"))
)
part_folders
# Out:
# [PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4')]

# %%
s2_imgs = []
s2_img_L2A = []
for folder in part_folders:
    s2_imgs.extend(list(folder.rglob("*sentinel12_s2_*_img.tif")))
    s2_img_L2A.extend(list(folder.rglob("*sentinel12_s2_*_L2A*.tif")))

if not do_L2A:
    s2_imgs = [x for x in s2_imgs if x not in s2_img_L2A]
len(s2_imgs)
# Out:
# 130

# %%
s2_imgs
# Out:
# [PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/75/sentinel12_s2_75_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/75/sentinel12_s2_75_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/78/sentinel12_s2_78_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/78/sentinel12_s2_78_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/76/sentinel12_s2_76_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/76/sentinel12_s2_76_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/77/sentinel12_s2_77_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/77/sentinel12_s2_77_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/73/sentinel12_s2_73_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/73/sentinel12_s2_73_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/80/sentinel12_s2_80_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/80/sentinel12_s2_80_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/82/sentinel12_s2_82_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/82/sentinel12_s2_82_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/71/sentinel12_s2_71_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part5/71/sentinel12_s2_71_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/8/sentinel12_s2_8_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/8/sentinel12_s2_8_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/5/sentinel12_s2_5_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/5/sentinel12_s2_5_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/7/sentinel12_s2_7_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/7/sentinel12_s2_7_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/9/sentinel12_s2_9_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/9/sentinel12_s2_9_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/11/sentinel12_s2_11_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/11/sentinel12_s2_11_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/16/sentinel12_s2_16_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/16/sentinel12_s2_16_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/1/sentinel12_s2_1_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/1/sentinel12_s2_1_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/6/sentinel12_s2_6_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/6/sentinel12_s2_6_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/10/sentinel12_s2_10_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/10/sentinel12_s2_10_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/13/sentinel12_s2_13_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/13/sentinel12_s2_13_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/15/sentinel12_s2_15_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/15/sentinel12_s2_15_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/12/sentinel12_s2_12_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part1/12/sentinel12_s2_12_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/93/sentinel12_s2_93_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/93/sentinel12_s2_93_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/83/sentinel12_s2_83_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/83/sentinel12_s2_83_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/88/sentinel12_s2_88_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/88/sentinel12_s2_88_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/84/sentinel12_s2_84_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/84/sentinel12_s2_84_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/85/sentinel12_s2_85_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/85/sentinel12_s2_85_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/87/sentinel12_s2_87_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/87/sentinel12_s2_87_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/86/sentinel12_s2_86_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/86/sentinel12_s2_86_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/89/sentinel12_s2_89_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/89/sentinel12_s2_89_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/91/sentinel12_s2_91_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part6/91/sentinel12_s2_91_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/23/sentinel12_s2_23_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/23/sentinel12_s2_23_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/26/sentinel12_s2_26_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/26/sentinel12_s2_26_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/22/sentinel12_s2_22_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/22/sentinel12_s2_22_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/30/sentinel12_s2_30_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/30/sentinel12_s2_30_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/21/sentinel12_s2_21_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/21/sentinel12_s2_21_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/27/sentinel12_s2_27_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/27/sentinel12_s2_27_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/28/sentinel12_s2_28_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/28/sentinel12_s2_28_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/19/sentinel12_s2_19_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/19/sentinel12_s2_19_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/29/sentinel12_s2_29_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/29/sentinel12_s2_29_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/25/sentinel12_s2_25_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/25/sentinel12_s2_25_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/17/sentinel12_s2_17_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/17/sentinel12_s2_17_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/31/sentinel12_s2_31_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part2/31/sentinel12_s2_31_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/32/sentinel12_s2_32_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/32/sentinel12_s2_32_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/49/sentinel12_s2_49_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/49/sentinel12_s2_49_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/35/sentinel12_s2_35_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/35/sentinel12_s2_35_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/48/sentinel12_s2_48_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/48/sentinel12_s2_48_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/37/sentinel12_s2_37_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/37/sentinel12_s2_37_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/36/sentinel12_s2_36_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/36/sentinel12_s2_36_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/39/sentinel12_s2_39_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/39/sentinel12_s2_39_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/33/sentinel12_s2_33_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/33/sentinel12_s2_33_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/47/sentinel12_s2_47_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/47/sentinel12_s2_47_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/51/sentinel12_s2_51_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/51/sentinel12_s2_51_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/40/sentinel12_s2_40_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/40/sentinel12_s2_40_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/41/sentinel12_s2_41_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part3/41/sentinel12_s2_41_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/59/sentinel12_s2_59_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/59/sentinel12_s2_59_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/65/sentinel12_s2_65_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/65/sentinel12_s2_65_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/57/sentinel12_s2_57_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/57/sentinel12_s2_57_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/54/sentinel12_s2_54_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/54/sentinel12_s2_54_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/52/sentinel12_s2_52_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/52/sentinel12_s2_52_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/68/sentinel12_s2_68_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/68/sentinel12_s2_68_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/69/sentinel12_s2_69_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/69/sentinel12_s2_69_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/62/sentinel12_s2_62_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/62/sentinel12_s2_62_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/55/sentinel12_s2_55_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/55/sentinel12_s2_55_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/67/sentinel12_s2_67_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/67/sentinel12_s2_67_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/53/sentinel12_s2_53_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/53/sentinel12_s2_53_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/64/sentinel12_s2_64_L2A_img.tif'),
#  PosixPath('/media/nick/4TB Working 6/Datasets/S1S2-Water/part4/64/sentinel12_s2_64_img.tif')]

# %%
def extract_patch(
    input_array: np.ndarray,
    top: int,
    bottom: int,
    left: int,
    right: int,
    input_raster_path: Path,
    dataset: str,
    src: rio.DatasetReader,
    patch_dir: Path,
    label: bool = False,
    background_value: int = 0,
    water_value: int = 1,
) -> None:
    patch = input_array[:, top:bottom, left:right]
    file_name = input_raster_path.stem
    file_name = file_name.replace("_msk", "")
    file_name = file_name.replace("_img", "")
    # file_name = file_name.replace(replace_for_mask, "")
    patch_path = patch_dir / f"{file_name}_{dataset}_{top}_{bottom}_{left}_{right}.tif"
    if patch_path.exists():
        return

    local_profile = src.profile.copy()
    local_profile.update(
        {"height": patch_size, "width": patch_size, "count": patch.shape[0]}
    )
    local_profile.update(
        {"transform": src.window_transform(window=((top, bottom), (left, right)))}
    )
    if label:
        patch[patch == 0] = background_value
        patch[patch == 1] = water_value
    if patch.shape[-2] != patch_size or patch.shape[-1] != patch_size:
        print(patch.shape)
        raise ValueError("Patch shape is not 512x512")

    with rio.open(patch_path, "w", **local_profile) as dst:
        dst.write(patch)

# %%
# for img in tqdm(s2_imgs):
def make_patches(img: Path) -> None:
    metadata = list(img.parent.glob("*meta.json"))[0]

    meta = json.load(metadata.open())
    dataset = meta["properties"]["split"]

    src = rio.open(img)
    img_array = src.read(image_bands)

    label_path = img.parent / img.name.replace("img", "msk").replace("_L2A", "")

    valid_path = img.parent / img.name.replace("img", "valid").replace("_L2A", "")

    label_src = rio.open(label_path)
    label_array = label_src.read()
    valid_array = rio.open(valid_path).read()
    # where array is 0 set label to 99
    label_array[valid_array == 0] = 99

    assert img_array.shape[0] == expected_image_channels, (
        f"Expected {expected_image_channels} channels, got {img_array.shape[0]}"
    )

    top = 0
    while True:
        bottom = top + patch_size
        left = 0
        while True:
            right = left + patch_size

            extract_patch(
                input_array=img_array,
                top=top,
                bottom=bottom,
                left=left,
                right=right,
                input_raster_path=img,
                src=src,
                dataset=dataset,
                patch_dir=img_patches_dir,
                label=False,
            )
            extract_patch(
                input_array=label_array,
                top=top,
                bottom=bottom,
                left=left,
                right=right,
                input_raster_path=label_path,
                src=label_src,
                dataset=dataset,
                patch_dir=mask_patches_dir,
                label=True,
                background_value=background_value,
                water_value=water_value,
            )

            left += stride
            right = left + patch_size

            if right >= label_array.shape[2]:
                break

        top += stride
        bottom = top + patch_size

        if bottom >= label_array.shape[1]:
            break

# %%
with ThreadPool(16) as p:
    results = list(tqdm(p.imap(make_patches, s2_imgs), total=len(s2_imgs)))
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]

# %%
def check_imgs(patch_path):
    try:
        array = rio.open(patch_path).read()
    except Exception as e:
        print(f"{patch_path} failed check {e}")
        return
    try:
        assert array.shape[-2] == patch_size
        assert array.shape[-1] == patch_size
        # assert array.shape[0] == 6
    except AssertionError:
        print(f"{patch_path} failed check, {array.shape}")
    try:
        file_name = patch_path.name
        label_file_name = file_name.replace("_L2A", "")
        label_path = mask_patches_dir / label_file_name
        assert label_path.exists()
    except AssertionError:
        print(f"{label_path} does not exist")


def check_masks(patch_path):
    try:
        array = rio.open(patch_path).read()
    except Exception as e:
        print(f"{patch_path} failed check {e}")
        return
    try:
        assert array.shape[-2] == patch_size
        assert array.shape[-1] == patch_size
        assert array.shape[0] == 1
    except AssertionError:
        print(f"{patch_path} failed check, {array.shape}")
    try:
        assert np.all(np.isin(array, [0, 1, 99]))
    except AssertionError:
        print(f"{patch_path} failed check, {np.unique(array)}")

# %%
img_patches = list(img_patches_dir.rglob("*.tif"))
mask_patches = list(mask_patches_dir.rglob("*.tif"))
print(len(img_patches), len(mask_patches))
# Out:
# 87880 43940

# %%
if do_L2A:
    assert len(img_patches) // 2 == len(mask_patches)
else:
    assert len(img_patches) == len(mask_patches)

# %%
with Pool(4) as p:
    results = list(tqdm(p.imap(check_imgs, img_patches), total=len(img_patches)))
# Out:
#   0%|          | 0/87880 [00:00<?, ?it/s]

# %%
with Pool(4) as p:
    results = list(tqdm(p.imap(check_masks, mask_patches), total=len(mask_patches)))
# Out:
#   0%|          | 0/43940 [00:00<?, ?it/s]
# /media/nick/4TB Working 6/Datasets/S1S2-Water/train/labels/sentinel12_s2_7_val_824_1336_2472_2984.tif failed check sentinel12_s2_7_val_824_1336_2472_2984.tif: MissingRequired:TIFF directory is missing required "ImageLength" field
# /media/nick/4TB Working 6/Datasets/S1S2-Water/train/labels/sentinel12_s2_62_val_412_924_1648_2160.tif failed check sentinel12_s2_62_val_412_924_1648_2160.tif: TIFFReadDirectory:Failed to read directory at offset 384
# /media/nick/4TB Working 6/Datasets/S1S2-Water/train/labels/sentinel12_s2_31_test_1236_1748_824_1336.tif failed check sentinel12_s2_31_test_1236_1748_824_1336.tif: MissingRequired:TIFF directory is missing required "ImageLength" field
# /media/nick/4TB Working 6/Datasets/S1S2-Water/train/labels/sentinel12_s2_47_test_6592_7104_10300_10812.tif failed check sentinel12_s2_47_test_6592_7104_10300_10812.tif: MissingRequired:TIFF directory is missing required "ImageLength" field
